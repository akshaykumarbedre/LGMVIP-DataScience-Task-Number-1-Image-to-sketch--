# %%
import cv2 
import matplotlib.pylab as plt

# %%
# Read the image
image_path="img copy.png"
img = cv2.imread(image_path)
plt.imshow(img)

# %%
# Convert to grey scale
grey_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(grey_img, cmap='gray')

# %%
# Invert the image
invert_img = cv2.bitwise_not(grey_img)
plt.imshow(invert_img, cmap='gray')

# %%
 # Blur the image
blur_img = cv2.GaussianBlur(invert_img, (21, 21), sigmaX=0, sigmaY=0)
plt.imshow(blur_img, cmap='gray')

# %%
# Invert the blurred image
invblur_img = cv2.bitwise_not(blur_img)
plt.imshow(invblur_img, cmap='gray')

# %%
# Sketch
sketch_img = cv2.divide(grey_img, invblur_img, scale=240.0)

# %%
cv2.imwrite('sketch.png', sketch_img)
# Out:
# True

# %%
plt.imshow(sketch_img,cmap="gray")
plt.show()

# %%
import cv2


def convert_to_sketch(image_path):
    # Read the image
    img = cv2.imread(image_path)
    
    # Convert to grey scale
    grey_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Invert the image
    invert_img = cv2.bitwise_not(grey_img)
    
    # Blur the image
    blur_img = cv2.GaussianBlur(invert_img, (21, 21), sigmaX=0, sigmaY=0)
    
    # Invert the blurred image
    invblur_img = cv2.bitwise_not(blur_img)
    
    # Sketch
    sketch_img = cv2.divide(grey_img, invblur_img, scale=256.0)
    
    # Save the sketch
    cv2.imwrite('sketch.png', sketch_img)
    
    # Display the sketch
    cv2.imshow('Sketch Image', sketch_img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# Path to the input image
image_path = 'img copy.png'

# Convert the image to a sketch
convert_to_sketch(image_path)
